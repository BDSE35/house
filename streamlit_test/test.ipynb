# %%
import pandas as pd
df = pd.read_csv('data/XGboost_weight_per_year.csv')
df
# Out:
#     Unnamed: 0      屋齡等級      有無電梯      新型建材    外圍迎毗設施  建物移轉總面積坪    外圍嫌惡設施  \
# 0         2013  0.329273  0.132175  0.089081  0.072234  0.057760  0.053655
# 1         2014  0.210073  0.074796  0.086640  0.056972  0.041599  0.033752
# 2         2015  0.289471  0.073288  0.116456  0.041239  0.053488  0.044885
# 3         2016  0.324261  0.101453  0.122060  0.041141  0.037522  0.048363
# 4         2017  0.278667  0.108569  0.181700  0.040006  0.039192  0.032265
# 5         2018  0.273782  0.115470  0.074802  0.044667  0.051823  0.048029
# 6         2019  0.261632  0.158196  0.046172  0.040219  0.047882  0.060988
# 7         2020  0.241245  0.086267  0.048967  0.038469  0.030072  0.033330
# 8         2021  0.242537  0.055491  0.019804  0.044641  0.028145  0.047203
# 9         2022  0.249110  0.035112  0.021122  0.019576  0.018312  0.031979
# 10        2023  0.135712  0.021067  0.011137  0.015764  0.010725  0.017805
# ...

# %%
import pandas as pd
df1 = pd.read_csv('data/Random Forest-Random Forest.csv')

# %%
a= list(df1["時間段 2012-2017 特徵重要性："])
a
# Out:
# ['南科房屋交易密度1km       ',
#  '建物移轉總面積坪           ',
#  '屋齡區間_未滿3年          ',
#  '嫌惡設施_1000m_1500m   ',
#  '嫌惡設施_500m_1000m    ',
#  '迎毗設施_1000m_1500m   ',
#  '嫌惡設施_0m_500m       ',
#  '建材種類_鋼筋            ',
#  '交易日                ',
#  '迎毗設施_500m_1000m    ']

# %%
df = pd.read_csv('data/房價_201010row_outlier_final_KDEclass (1).csv')
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_26460\4158108376.py:1: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/房價_201010row_outlier_final_KDEclass (1).csv')

# %%
df.columns
# Out:
# Index(['鄉鎮市區', '土地位置建物門牌', '交易年月日', '建築完成年月', '建物移轉總面積平方公尺', '有無管理組織', '總價元',
#        '單價元平方公尺', '備註', '編號', '緯度', '經度', 'bad_count', 'good_count', '建築型態清整',
#        '陽台有無', '是否含額外土地', '建築型態_住商大樓', '建築型態_公寓', '建築型態_其他', '建築型態_透天厝',
#        '房地總價元', '格局比例_房', '格局比例_廳', '格局比例_衛', '格局比例_隔間', '是否包含車位', '建材_磚石',
#        '建材_鋼筋', '建材_鋼骨', '建材_竹木', '住', '商', '工', '農', '移轉層次_騎樓', '移轉層次_屋頂',
#        '移轉層次_一二樓', 'KDE_0.5km', 'KDE_1km', 'KDE_1.5km', '有無電梯', 'Region',
#        '建物移轉總面積坪', '單價元每坪', '房地總價元(坪)', '交易年份', '建築完成年', '交易年_民國', '屋齡',
#        '屋齡區間', 'good_count_0_500', 'good_count_500_1000',
#        'good_count_1000_1500', 'bad_count_0_500', 'bad_count_500_1000',
#        'bad_count_1000_1500', 'KDE_class'],
#       dtype='object')

# %%
df1 = df[['編號', '緯度', '經度', 'KDE_0.5km', 'KDE_1km', 'KDE_1.5km', 'KDE_class', 'Region']]

# %%
df1.columns
# Out:
# Index(['編號', '緯度', '經度', 'KDE_0.5km', 'KDE_1km', 'KDE_1.5km', 'KDE_class',
#        'Region'],
#       dtype='object')

# %%
df1.to_csv('map.csv', index=False)

# %%
df2 = df[['編號', '交易年份', '緯度', '經度', 'KDE_0.5km', 'KDE_1km', 'KDE_1.5km', 'KDE_class', 'Region']]

# %%
df1.to_csv('map.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv('data/map.csv')
df
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_29488\753758425.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/map.csv')
#                          編號  交易年份         緯度          經度  KDE_0.5km   KDE_1km  \
# 0       RPOOMLSJQHHGFAD97DA  2022  23.008977  120.228436   0.003506  0.001622
# 1       RPQNMLKKQHHGFGD97DA  2022  23.188924  120.192413   0.000497  0.000467
# 2       RPQNMLQJQHHGFGD48DA  2022  23.159399  120.171820   0.000522  0.000490
# 3       RPXNMLKKQHHGFAD08DA  2022  22.989076  120.171889   0.002654  0.001307
# 4       RPRNMLQKQHHGFKD56EA  2022  23.039165  120.239820   0.002744  0.001558
# ...                     ...   ...        ...         ...        ...       ...
# 201005  RPVNMLLLKHJGFBD77CB  2024  23.056343  120.209113   0.001191  0.000533
# 201006  RPPNMLSKLHJGFHD48DA  2024  23.072215  120.263897   0.001423  0.000572
# ...

# %%
df1 = df[['交易年份', '緯度', '經度']]

# %%
df1.columns
# Out:
# Index(['緯度', '經度'], dtype='object')

# %%
df1 = df1.rename(columns={'經度': 'latitude', '緯度': 'longitude'})

# %%
df1.to_csv('data/mapxy.csv', index=False)

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\student\Documents\GitHub\-\streamlit_test
